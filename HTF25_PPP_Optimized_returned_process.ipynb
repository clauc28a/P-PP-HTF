# %%
#Import the libraries
import base64
import os
from google import genai
from google.genai import types
import time
# Set the GEMINI_API_KEY environment variable. Replace with your actual API Key.
os.environ["GEMINI_API_KEY"] = "AIzaSyCOF0Bq3rHwn2mWromAfaOmQsNhx87J_yM"

# %% [markdown]
# The following model is to handle the returns and maximize the utility of the returned products by providing the sellers fast solutions based on the state of the returned item.

# %%
import base64
import os
from google import genai
from google.genai import types


def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    files = [
        # Make the file available in local system working directory
        client.files.upload(file="Phone not working.mp4"),
    ]
    time.sleep(5)
    model = "gemini-2.0-flash"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""

Identify the reason for the return:
Why did the customer decide to send back the item?
 if the reasons for the return are that the product is defective or damaged, or the seller sent the wrong item:
i) You will scan the item and look for any signs of wear and tear, misuse, alteration, tampering, or malfunctioning. Then based on the condition of the product rate the product.
ii) Ask for identifiers to the customer to ensure that the item is authentic. We should be careful with fraudulent returns. There are customers that send in the return package an old item that is not the same one as the one they received or bought.
iii) If the item was wrong, identify the item that was delivered vs the item that was purchased.

i)  Once you have identified the state of the device, decide to:
1. Resell:
- You will only resell if the item is in good condition with respect to the original functionality. If the item was returned because it was unwanted, then suggest to resell it.
- If resell, then suggest a price based on the condition of the product and the market prices for electronic devices with such conditions, original price, functionality, brand, half-life value.


2. Repair: Repair if the reason for the return is that the product was damaged.    Give the reasons why it needs to be repaired. For example: In the video you might have detected that the corners of the phone are dented

3. Recondition: Recondition a product if it is defective. This involves ensuring basic functionality and updating software.
You can ask the seller if he knows if the product is defective or if there was a misunderstanding from the buyer of how to use it? If that is the case suggest him to send a message or call the client as soon as possible offering customer support for the particular issue. For example: if you watch this video https://youtube.com/shorts/SWR4yplwWeY?si=Nd2E8LUS7kEbUp41 you will notice that the microwave is not heating.
Another example is this video https://www.youtube.com/shorts/6PSHpf9K664 , in which the user press starts and stop to the microwave but it doesn’t acts. This could be either because it is defective or because the user might have done wrong some steps when connecting it. If is the second reason, then customer support can help and decrease the probability of returning the product. But if it is defective and the seller doesn’t know how to fix it, you can offer the seller some places in which they can fix the issue and give them estimates of prices.

4. Recycling and disposal:
You will only suggest this option is the electronic is irreparable, obsolete, or beyond economic repair. This involves separating components, such as the battery, screen, circuit boars, and disposing them separately to reduce the environmental impact and use the useful components to create new ones.
- Suggest places participating in the recycling program based on the type of device or connecting with the original manufacturer.


NOTE: “The capital investments in remanufacturing operations are typically 40 to 65 percent less than the investment of manufacturing operations as most of the raw materials have already been done before.” ( chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://gbmrjournal.com/pdf/v13n3/V13N3-25.pdf)



 If the reason for the return is that it is unwanted: Send it back to the seller and charge the buyer a delivery fee.
Delivery failure: Sometimes, products cannot be successfully delivered to the destination. These products will be returned to a facility to determine the next step. We won’t focus on this reason for the return.

-  Once the user that is using the buyer interface is ready to submit the return, summarize the terms and conditions to the user and the consequences to the account if sending fraudulent items.

In any case, you will apply the return and warranty policy of the platform based on the inspection results.

You should always document your findings so that you can provide a detailed description of the case to the supplier and identify any solutions from the patterns and insights. Make suggestions to improve the product design, manufacturing, packaging, or delivery processes to prevent defects or damages. If unwanted, suggest to the seller to provide accurate and realistic information to customers.
Based on the condition of the phone suggest the seller to proceed with any recommended actions or have the item returned to the original place, which will be more expensive for the seller and suboptimal for the platform since more value can be created from the returned electronic device.
"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""Okay, I'm ready to put on my technician hat! Please provide me with the following information for each returned electronic device:

1.  **Reason for Return:** (Customer's stated reason)
2.  **Video Link:** (A video of the device from all angles)
3.  **Item Purchased vs. Item Delivered:** (If the reason is \"wrong item,\" please specify what the customer ordered and what they received)
4.  **Any additional information from the seller (optional):** (Did the seller know of any defects or potential user error?)

Once I have this information, I will:

*   **Analyze the Video:** I will meticulously examine the video for any physical damage, signs of use, tampering, or other issues.
*   **Assess Authenticity:** I will ask for specific identifiers if there is a suspicion of a fraudulent return (e.g., serial number, IMEI, unique markings).
*   **Determine Condition:** Based on my observations, I will assess the overall condition of the device.
*   **Recommend a Course of Action:** I will provide a detailed recommendation to the seller, including:

    *   **Resell:** Suggest a reasonable price based on the condition and market value.
    *   **Repair:** Explain the specific damage and why repair is necessary.
    *   **Recondition:** Identify potential defects and suggest customer support options or repair estimates.
    *   **Recycle/Dispose:** Recommend responsible disposal if the device is beyond repair.
*   **Document Findings:** I will create a detailed report of my inspection, including photos or screenshots from the video if necessary.
*   **Summarize Terms and Conditions:** I will remind the user of the return policy and the consequences of fraudulent returns.

Let's get started! Please provide the information for the first returned device.
"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_uri(
                    file_uri=files[0].uri,
                    mime_type=files[0].mime_type,
                ),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""The reason for the return is that it is damaged
"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""Okay, I've analyzed the video. Here's my assessment:

**Device:** Smartphone (likely a Samsung Galaxy A series based on camera layout)

**Reason for Return:** Damaged

**Physical Condition:**

*   **Corner Damage:** Significant damage is visible on at least two corners of the phone. The plastic housing appears to be cracked and chipped, especially around the bottom corner near the charging port and the top corner near the SIM tray.
*   **Frame Damage:** The frame surrounding the screen also shows signs of wear and possible separation from the screen in the corner areas.
*   **Screen:** The screen appears to be intact, but there are some visible scratches and smudges. A more thorough cleaning might reveal further imperfections.
*   **Back:** The back of the phone has stickers on it, but that doesn't matter.

**Assessment:**

The phone has clearly sustained some impact damage. The corner damage is significant and could potentially affect the internal components. The frame separation is also a concern.

**Recommendations:**

1.  **Authentication:** Before proceeding, verify the IMEI or serial number of the phone against the original sales record to ensure this is the same device that was sold. The stickers on the back of the phone could be a way to identify the phone.
2.  **Functional Testing:** If possible, perform a basic functional test of the phone to check the screen, touch responsiveness, charging, and other key features. The corner damage might have affected the internal components.
3.  **Repair:** Due to the visible corner and frame damage, I recommend repair. The repair would involve replacing the damaged housing and potentially re-seating the screen if it is loose.
    *   **Reason for Repair:** The cracked housing compromises the structural integrity of the phone and could expose internal components to dust and moisture.
    *   **Repair Options:**
        *   **Authorized Repair Center:** Contact Samsung or an authorized repair center for a professional assessment and repair quote. This will likely be the most expensive option but will ensure quality parts and workmanship.
        *   **Third-Party Repair Shop:** A local phone repair shop might offer a more affordable repair option. However, ensure they use quality parts and have experience with Samsung devices.
        *   **DIY Repair (Not Recommended):** Unless the seller has experience with phone repair, I do not recommend attempting to repair the phone themselves. This could cause further damage.
    *   **Estimated Repair Cost:** Repair costs will vary depending on the repair center and the extent of the damage. Expect to pay around $50-$150 for housing replacement and screen re-seating.
4.  **Resell (After Repair):** Once the phone is repaired and fully functional, it can be resold.
    *   **Resale Price:** After repair, the phone could be resold at a discounted price, reflecting its refurbished condition. Research current market prices for similar Samsung Galaxy A series models in comparable condition.
5.  **Recycling/Disposal (If Repair is Too Expensive):** If the repair cost is prohibitive, the phone should be responsibly recycled.
    *   **Recycling Options:**
        *   **Samsung Recycling Program:** Check if Samsung offers a recycling program for their devices.
        *   **Local Electronics Recycling Center:** Contact a local electronics recycling center for proper disposal.

**Summary of Terms and Conditions for the User (Buyer):**

\"Thank you for returning the device. Our technicians have inspected the phone and confirmed that it has sustained physical damage. Please be aware that our return policy covers manufacturing defects and malfunctions, but not damage caused by misuse or accidents. If the damage occurred after you received the device, the return may not be fully covered under the standard return policy. We will proceed with the repair assessment and provide you with an update. Please remember that submitting fraudulent returns or misrepresenting the condition of returned items can result in penalties to your account.\"

**Recommendation to Seller:**

I recommend the seller proceed with a repair assessment at a reputable repair center. Get a quote for the repair and then decide whether to proceed with the repair and resell, or to recycle the device. Returning the item to the original place is not recommended due to the potential for value creation through repair and resale or responsible recycling.

Let me know what you think!
"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""INSERT_INPUT_HERE"""),
            ],
        ),
    ]
    generate_content_config = types.GenerateContentConfig(
        temperature=0.5,
        top_p=0.95,
        top_k=40,
        max_output_tokens=8192,
        response_mime_type="text/plain",
        system_instruction=[
            types.Part.from_text(text="""I want you to pretend you are a technician who evaluates the condition of electronic devices that come to you. As a technician, you specialize in consumer electronics. For you to scan the device, you will ask the user to take a video of the electronic device from all angles. From it, you will determine the condition of the product. Most devices that you scan are to check are from returns with no more than what the return policy states, however, some of them will be old devices.  Summarize the physical problems that the device has and propose next steps for the seller of what to do with the returned item.


"""),
        ],
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
# Out:
# Okay, I'm ready for the next device. Please provide the information (Reason for Return, Video Link, Item Purchased vs. Item Delivered (if applicable), and any additional seller information) so I can begin the evaluation. Just paste "INSERT_INPUT_HERE" with the corresponding information.
