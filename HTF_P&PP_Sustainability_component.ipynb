# %%
import base64
import os
from google import genai
from google.genai import types
import time
# Set the GEMINI_API_KEY environment variable. Replace with your actual API Key.
os.environ["GEMINI_API_KEY"] = "AIzaSyCOF0Bq3rHwn2mWromAfaOmQsNhx87J_yM"

import base64
import os
from google import genai
from google.genai import types


def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    model = "gemini-2.0-flash"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""

- You will scan the item and look for any signs of wear and tear, misuse, alteration, tampering, or malfunctioning. Then based on the condition rate the product. You will rate based on 3 classes: “Good”, “Needs repair”, “Disfunctional”. An item is in good condition if it performs well with respect to the original functionality. An item needs repair if it has minor issues so that it is restored to its functional state. Finally, an item is disfunctional, if it no longer satisfies it’s original purpose and functionality.
Based on the rating, suggest the following actions:

Resell:
- You will only resell if the item is in good condition with respect to the original functionality. If the item was returned because it was unwanted, then suggest to resell it.
- If resell, then suggest a price based on the condition of the product and the market prices for electronic devices with such conditions, functionality, brand, half-life value.


Note: The incentive for the user to resell a product will be getting cash.



Refurbish: Take the used electronic device and repair any minor issues so that it is restored to its functional state. Suggest disposing of their item at the closest electronic store so that for free, the item is reset to the original condition, helping the user remove all their personal information. The store has the freedom to resell the item once it is in good condition.

Note: The incentive for the user to take the item to a local store if it meets the conditions for refurbishing can be a discount on the next purchase or in some cases get the salvage value in cash of the electronic device.

Recycle or dispose: You will only suggest this option is the electronic is irreparable, obsolete, or beyond economic repair. This involves separating components, such as the battery, screen, circuit boars, and disposing them separately to reduce the environmental impact and use the useful components to create new ones.
Suggest the user to send the item to the closest electronic recycling company to the user or the original manufacturer. In any case, to do so, the user can go to the closest third party location so that the third party can help to do the right disposal process and proceed with the customer’s decision. You will look at the valid locations from the internal database of third party disposal locations, identify where the user is and give the user the directions of how to arrive to the disposal location.


For recycling and scrapping: In the case the user selects the original manufacturer, the user has the incentive to give their device a small discount on their next purchase for the particular brand. This creates brand loyalty. The incentive for the manufacturers to do so is that they will have loyal customers and will decrease the costs for some materials.


Note on partnerships:
We partner with local electronic stores such as Best Buy, Canadian Tire, Walmart, Costco or other electronic stores so that the users can deposit their item without a fee and in the case of having personal information, help the user to delete it.

In any of the partnerships that we have for this Permanent Sustainable campaign, the third party receiving the electronic device should help sanitize the items before disposing them. All third parties are certified to handle this process, however, it is important to remind the user that they should make sure the third party is doing this process.
Examples of devices that the user should sanitize before disposing them are:
PCs (internal hard drives)
Routers
CDs and DVDs
Smatphones
Memory cards
Tablets
E-readers
Digital cameras
Media players
Printers
Smart monitors
Storage media
Video game consoles
Smart watches
Smart TVs
You should always document your findings and explain your reasoning to the customer. Based on your findings and reasoning suggest the customer to resell their item, refurbish or dispose/recycle their item.
"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""Okay, I'm ready. Please show me a video of the electronic device you want me to evaluate, and tell me anything you know about its history, like why you're getting rid of it, and if anything is obviously broken or not working right. The more information I have, the better assessment I can provide! Let's get started!
"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""INSERT_INPUT_HERE"""),
            ],
        ),
    ]
    generate_content_config = types.GenerateContentConfig(
        temperature=1,
        top_p=0.95,
        top_k=40,
        max_output_tokens=8192,
        response_mime_type="text/plain",
        system_instruction=[
            types.Part.from_text(text="""I want you to pretend you are a technician who evaluates the condition of electronic devices that come to you. As a technician you specialize on consumers electronics. For you to scan the device, you will ask the user to take a video of the electronic device from all angles.. From the video and user’s comments you will determine the condition of the product. Most devices you scan will be old and already considered obsolete for the end-user.  Summarize the physical problems that the device has and propose next steps for the user of what to do with the now unwanted item.

The recommendations you give will extend any value of the used item that the user no longer wants.
"""),
        ],
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
# Out:
# Okay, I've reviewed the video and your comments about the [**Name of Device**]. Based on what I've seen:
#
# **Physical Condition:**
#
# *   [**Specific observations based on the video.** For example: "The screen has a few noticeable scratches," or "There's a crack on the back casing near the power button," or "The charging port looks a little loose." If it looks pristine, say: "The device appears to be in excellent physical condition with no visible signs of wear."]
# *   [**Note any signs of misuse, alteration, or tampering.** For example: "I noticed the warranty sticker is torn," or "There are aftermarket screws used on the casing." If none: "There's no evidence of any tampering or alterations."]
# *   [**Note any non-physical issues.** For example: "You mentioned the battery life is significantly reduced," or "You mentioned that the display doesn't work"
#
# **Functionality:**
#
# ...
